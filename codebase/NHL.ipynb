# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # NHL Analytics

# %%
import os
import sys

from ift6758.data import get_data, tidy_data, PlayByPlayWidget

# %% [markdown]
# ### Data Acquisition

# %%
#Downloading the raw data using NHL API
nhl_data = get_data(2016, 2020, './ift6758/data/NHL/')
# Out:
# Loading 2016-2017 regular_season data
# Loading 2016-2017 playoffs data

# %% [markdown]
# ### Play By Play Widget

# %%
# Load the data for season 2020-2021
season = get_data(2020, 2020, './ift6758/data/NHL/')
# Out:
# Loading 2020-2021 regular_season data
# Loading 2020-2021 playoffs data

# %%
#create and widget and dipslay
pbp = PlayByPlayWidget(season)
pbp.display()

# %% [markdown]
# ### Tidy the Data
#
# Clean the data obtained from  NHL API using `get_data` and convert into `csv` format.

# %%
import pandas as pd
# change the raw data into dataframe 
event_types = ['Shot','Goal']
tidy_data(2016, 2017, './ift6758/data/NHL/', event_types)
df = pd.read_csv('./ift6758/data/NHL/2016.csv')
df.head(10)
# Out:
#    Unnamed: 0              gameTime      gameId                 team  \
# 0           0  2016-10-12T23:00:00Z  2016020001  Toronto Maple Leafs
# 1           1  2016-10-12T23:00:00Z  2016020001      Ottawa Senators
# 2           2  2016-10-12T23:00:00Z  2016020001      Ottawa Senators
# 3           3  2016-10-12T23:00:00Z  2016020001      Ottawa Senators
# 4           4  2016-10-12T23:00:00Z  2016020001  Toronto Maple Leafs
# 5           5  2016-10-12T23:00:00Z  2016020001  Toronto Maple Leafs
# 6           6  2016-10-12T23:00:00Z  2016020001  Toronto Maple Leafs
# 7           7  2016-10-12T23:00:00Z  2016020001  Toronto Maple Leafs
# 8           8  2016-10-12T23:00:00Z  2016020001      Ottawa Senators
# 9           9  2016-10-12T23:00:00Z  2016020001      Ottawa Senators
#
#   eventType  coordinates_x  coordinates_y          shooter             goalie  \
# 0      Shot          -77.0            5.0  Mitchell Marner     Craig Anderson
# ...

# %% [markdown]
# ### Simple Visualizations

# %%
from ift6758.viz import compare_shot_types, goal_and_shot_distances, goal_and_shot_distances_types
import pandas as pd

# %%
target_season = 2019
df = pd.read_csv(os.path.join('./ift6758/data/NHL', f"{target_season}.csv"))
compare_shot_types(df)

# %%
target_season = 2019
df = pd.read_csv(os.path.join('./ift6758/data/NHL', f"{target_season}.csv"))
goal_and_shot_distances(df)
# Out:
# /Users/yujunzhong/Documents/study/UdeM+Mila/Courses/IFT6758/projects/ds-project-tm9/milestone1_codebase/ift6758/visualizations/simple_visualizations.py:40: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   groups = df.groupby(df['bins'])['eventType', 'distances']

# %%
target_season = 2019
df = pd.read_csv(os.path.join('./ift6758/data/NHL', f"{target_season}.csv"))
goal_and_shot_distances_types(df)
# Out:
# /Users/yujunzhong/Documents/study/UdeM+Mila/Courses/IFT6758/projects/ds-project-tm9/milestone1_codebase/ift6758/visualizations/simple_visualizations.py:65: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   groups = df.groupby(dist_cut)['eventType', 'shotType', 'distances']

# %% [markdown]
# ### Advanced Visualizations

# %%
from ift6758.viz import crop_half_rink, advanced_visualizations

# %%
rink_file = "./figures/nhl_rink.png"
half_rink = "./figures/right.jpg"
crop_half_rink(rink_file, half_rink)

year = 2017
advanced_visualizations(year, half_rink)
