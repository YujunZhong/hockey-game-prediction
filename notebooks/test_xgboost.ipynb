# %%
import pandas as pd
from run_xgboost import proc_feats

df = pd.read_csv('../../notebooks/tmp/nhl/nhl_data_clean.csv')
new_df = proc_feats(df)
new_df.head(5)
# Out:
#    Unnamed: 0             date_time     season     game_id game_type  \
# 0           0  2015-10-07T23:24:23Z  2015-2016  2015020001         R
# 1           1  2015-10-07T23:24:38Z  2015-2016  2015020001         R
# 2           2  2015-10-07T23:27:21Z  2015-2016  2015020001         R
# 3           3  2015-10-07T23:25:24Z  2015-2016  2015020001         R
# 4           4  2015-10-07T23:27:08Z  2015-2016  2015020001         R
#
#    game_seconds  period period_time  period_seconds  event_type  ...  \
# 0            51       1       00:51              51           0  ...
# 1            65       1       01:05              65           0  ...
# 2            66       1       01:06              66           0  ...
# 3           113       1       01:53             113           0  ...
# 4           157       1       02:37             157           0  ...
#
#    shot_distance  shot_angle distance_from_prev_event  time_from_prev_event  \
# 0          34.53       10.01                   154.28                    11
# 1          10.00        0.00                    50.48                     7
# 2          14.04        4.09                     4.12                     1
# 3          49.52       46.64                    79.61                    18
# 4          28.02        2.05                    22.47                     5
#
#    rebound  change_in_angle  speed shot_type empty_net strength
# 0        0             0.00  14.03         7         0     Even
# 1        0             0.00   7.21         4         0     Even
# 2        1             4.09   4.12         4         0     Even
# 3        0             0.00   4.42         7         0     Even
# 4        0             0.00   4.49         5         0     Even
#
# [5 rows x 31 columns]

# %%
from run_xgboost import train_xgboost

train_xgboost(new_df, feat_num=2)

# %%
from sklearn.model_selection import train_test_split

feat_list = ['game_seconds', 'period', 'coord_x', 'coord_y', 'shot_distance', 'shot_angle', 'shot_type', 'prev_event_type', 'prev_coord_x', 'prev_coord_y', 
        'time_from_prev_event', 'distance_from_prev_event', 'rebound', 'change_in_angle', 'speed', 'empty_net']

feats = new_df[feat_list]
label = new_df[['event_type']]

X_train, X_val, y_train, y_val = train_test_split(feats, label, test_size=0.1)

# %%
from xgboost import XGBClassifier
# import packages for hyperparameters tuning
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV

hyperparams = {'booster': ['gbtree', 'gblinear', 'dart'],
              'objective':['binary:logistic'],
              'eta': [1, 0.1, 0.05],       # learning rate
              'max_depth': [3, 10, 18],
            #   'gamma': [0, 3, 6, 9],
            #   'min_child_weight': [0, 4, 7, 11],
              'subsample': [0.5, 1],
              'eval_metric': ['auc'],
              'seed': [1337]
              }

xgb_model = XGBClassifier()
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=0)

clf = GridSearchCV(xgb_model, hyperparams, n_jobs=1, 
                   cv=skf,
                   scoring='roc_auc',
                   verbose=2, refit=True)

clf.fit(feats, label)
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   2.9s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   2.7s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   2.9s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   2.1s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   2.0s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   2.0s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  10.2s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  10.0s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=   9.9s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   8.7s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   8.9s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   9.9s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  18.1s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  18.5s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  18.2s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  18.1s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  18.0s
# [CV] END booster=gbtree, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  18.0s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   2.9s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   2.9s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   2.9s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   2.2s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   2.2s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   2.2s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  10.1s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  10.2s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  10.2s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   8.9s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   8.8s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   9.0s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  19.7s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  19.7s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  20.0s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  19.9s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  18.9s
# [CV] END booster=gbtree, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  20.2s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   3.3s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   3.7s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   3.1s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   2.4s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   2.4s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   2.4s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  12.0s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  12.2s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  10.9s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   9.7s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   9.6s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   9.6s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  20.0s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  19.9s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  20.1s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  20.9s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  21.2s
# [CV] END booster=gbtree, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  21.5s
# [15:10:19] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:20] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:21] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:22] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:23] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:25] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   0.7s
# [15:10:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:26] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.7s
# [15:10:28] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:29] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:30] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:31] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:32] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:33] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:34] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:35] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:36] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:37] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:38] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:39] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:40] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:41] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:42] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:43] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:44] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:46] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.7s
# [15:10:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:48] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=   0.7s
# [15:10:49] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=   0.6s
# [15:10:51] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:52] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=   0.6s
# [15:10:53] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "max_depth", "subsample" } are not used.
#
# [CV] END booster=gblinear, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=   0.7s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=  12.9s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=  12.9s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=  12.7s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=  12.9s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=  13.5s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=  13.3s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  26.5s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  25.8s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  25.6s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=  28.7s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=  31.8s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=  34.0s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  58.6s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  59.4s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time= 1.1min
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  54.1s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  53.0s
# [CV] END booster=dart, eta=1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  54.5s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=  15.8s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=  16.0s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=  16.2s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=  14.0s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=  14.1s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=  13.5s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  30.7s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  27.3s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  27.6s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=  25.0s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=  25.2s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=  24.9s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  45.5s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  43.5s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=10.3min
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  45.6s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  41.2s
# [CV] END booster=dart, eta=0.1, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  40.4s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=  11.8s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=  12.0s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=0.5; total time=  12.1s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=  11.3s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=  11.2s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=3, objective=binary:logistic, seed=1337, subsample=1; total time=  11.4s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  24.4s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  24.5s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=0.5; total time=  25.1s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=  23.8s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=  25.7s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=10, objective=binary:logistic, seed=1337, subsample=1; total time=  28.0s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  43.8s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  42.8s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=0.5; total time=  43.6s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  45.8s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  46.0s
# [CV] END booster=dart, eta=0.05, eval_metric=auc, max_depth=18, objective=binary:logistic, seed=1337, subsample=1; total time=  46.3s
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=0, shuffle=True),
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      gpu_id=None, grow_policy=None,
#                                      importance_type...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, ...),
#              n_jobs=1,
#              param_grid={'booster': ['gbtree', 'gblinear', 'dart'],
#                          'eta': [1, 0.1, 0.05], 'eval_metric': ['auc'],
#                          'max_depth': [3, 10, 18],
#                          'objective': ['binary:logistic'], 'seed': [1337],
#                          'subsample': [0.5, 1]},
#              scoring='roc_auc', verbose=2)

# %%
from sklearn_evaluation import plot

# grid_scores = clf.cv_results_
# print(grid_scores)

plot.grid_search(clf.cv_results_, change=('booster', 'eta'),
                 subset={'eval_metric': 'auc', 'max_depth': 10, 'objective': 'binary:logistic', 'seed': 1337, 'subsample': 0.5})
# plot.grid_search(clf.cv_results_, change=('max_depth', 'subsample'),
#                  subset={'eval_metric': 'auc','booster': 'dart', 'eta': 0.05, 'objective': 'binary:logistic', 'seed': 1337})

# print('Best AUC score:', clf.best_score_)
# print(clf.best_estimator_)
# print(clf.best_params_)

# test_probs = clf.predict_proba(X_val)[:,1]
# Out:
# <AxesSubplot: >

# %%
from run_xgboost import train_xgboost

xgboost_model, roc_auc = train_xgboost(new_df, feat_num=16)

# %%
xgboost_model.save_model('xgboost_all_feats.json')

# %%
# # Import comet_ml at the top of your file, before sklearn!
import os
from comet_ml import Experiment


# # Create an experiment with your api key
exp = Experiment(
    # api_key=os.environ.get('COMET_API_KEY'), # don’t hardcode!! 
    api_key='nswhJWNIpDxovklD8fxYpbxX4',
    project_name='ift6758-project',
    workspace='ds-team-9',
)

exp.log_model("models", "xgboost_all_feats.json")

exp.log_metrics({"auc": roc_auc})
# Out:
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, xgboost. Metrics and hyperparameters can still be logged using comet_ml.log_metrics() and comet_ml.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/ds-team-9/ift6758-project/3e573229f90f46e38ffae82de9df09f8
