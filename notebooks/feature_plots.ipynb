# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys

import numpy as np
import pandas as pd

# %%
module_path = os.path.abspath("../")
sys.path.append(module_path) #add parent directory to path to detect the modules

# %%
STORE_ENV = 'DATA_STORE_PATH'
os.environ[STORE_ENV] = './tmp/nhl' #set data store path as environment variable

# %%
path = os.environ.get(STORE_ENV)

# %% [markdown]
# **Load clean data**

# %%
df = pd.read_csv(f'{path}/nhl_data_clean_train.csv')

# %% [markdown]
# ## Feature Plots

# %%
from ift6758.viz import *

# %%
hist_dist_shot_counts(df)

# %%
hist_angle_shot_counts(df)

# %%
hist_dist_angle_shot_counts(df)

# %%
line_dist_goal_rate(df)

# %%
line_angle_goal_rate(df)

# %%
hist_dist_goal_empty_net(df)

# %%
hist_angle_goal_empty_net(df)
